# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Mall_Customers.csv')

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.shape
# Out:
# (200, 5)

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
sns.pairplot(df[['Spending Score (1-100)','Annual Income (k$)','Age']])
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import  sklearn.cluster as cluster

# %%
kmeans = cluster.KMeans(n_clusters=5)

# %%
kmeans = kmeans.fit(df[['Annual Income (k$)','Spending Score (1-100)']])
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
kmeans.cluster_centers_
# Out:
# array([[55.2962963 , 49.51851852],
#        [86.53846154, 82.12820513],
#        [25.72727273, 79.36363636],
#        [88.2       , 17.11428571],
#        [26.30434783, 20.91304348]])

# %%
df['income_cluster'] = kmeans.labels_

# %%
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      income_cluster
# 0                 4
# 1                 2
# 2                 4
# ...

# %%
df['income_cluster'].value_counts()
# Out:
# income_cluster
# 0    81
# 1    39
# 3    35
# 4    23
# 2    22
# Name: count, dtype: int64

# %%
sns.scatterplot(x='Annual Income (k$)',y='Spending Score (1-100)',hue='income_cluster',data=df)
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %%
from sklearn.cluster import KMeans

# %%
k_range = range(1,12)
wccs = []

# %%
for k in k_range:
    km = KMeans(n_clusters=K)
    KM.FIT(DF[['Annual Income (k$)','Spending Score (1-100)']])
    wcss.append(km.inertia_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 for k in k_range:
# ----> 2     km = KMeans(n_clusters=K)
#       3     KM.FIT(DF[['Annual Income (k$)','Spending Score (1-100)']])
#       4     wcss.append(km.inertia_)
#
# NameError: name 'K' is not defined
