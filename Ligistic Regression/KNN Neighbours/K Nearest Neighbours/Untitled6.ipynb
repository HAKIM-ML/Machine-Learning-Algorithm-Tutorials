# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Customer-Churn-Prediction.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
import seaborn as sns
def hist(plot):
    plt.figure(figsize=(10,5))
    sns.histplot(plot,kde=True)
    return hist

# %%
hist(df['MonthlyCharges'])
# Out:
# <function __main__.hist(plot)>

# %%
# hist(df['TotalCharges'])

# %%
df['Contract'].value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
df['Contract'] = df['Contract'].replace('Month-to-month','monthly')

# %%
df['Contract'] = df['Contract'].replace('Two year','yearly')

# %%
df['Contract'] = df['Contract'].replace('One year','yearly')

# %%
df.Contract.value_counts()
# Out:
# Contract
# monthly    3875
# yearly     3168
# Name: count, dtype: int64

# %%
df.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df['MultipleLines'].value_counts()
# Out:
# MultipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64

# %%
df['MultipleLines'] = df.MultipleLines.replace('No phone service','No')

# %%
df.MultipleLines.value_counts()
# Out:
# MultipleLines
# No     4072
# Yes    2971
# Name: count, dtype: int64

# %%
def count(plot2):
    plt.figure(figsize=(10,6))
    sns.countplot(x=plot2,data=df)
    return count

# %%
count(df['InternetService'])
# Out:
# <function __main__.count(plot2)>

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0            No             DSL             No  ...               No
# 1            No             DSL            Yes  ...              Yes
# 2            No             DSL            Yes  ...               No
# 3            No             DSL            Yes  ...              Yes
# 4            No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies Contract PaperlessBilling  \
# ...

# %%
count(df['StreamingTV'])
# Out:
# <function __main__.count(plot2)>

# %%
df['StreamingTV'] = df['StreamingTV'].replace('No internet service','No')

# %%
count(df['StreamingTV'])
# Out:
# <function __main__.count(plot2)>

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0            No             DSL             No  ...               No
# 1            No             DSL            Yes  ...              Yes
# 2            No             DSL            Yes  ...               No
# 3            No             DSL            Yes  ...              Yes
# 4            No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies Contract PaperlessBilling  \
# ...

# %%
count(df['TechSupport'])
# Out:
# <function __main__.count(plot2)>

# %%
df['TechSupport'] = df['TechSupport'].replace('TechSupport','No')

# %%
count(df['DeviceProtection'])
# Out:
# <function __main__.count(plot2)>

# %%
df['DeviceProtection'] = df['DeviceProtection'].replace('DeviceProtection','No')

# %%
df.head(3)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0            No             DSL             No  ...               No
# 1            No             DSL            Yes  ...              Yes
# 2            No             DSL            Yes  ...               No
#
#   TechSupport StreamingTV StreamingMovies Contract PaperlessBilling  \
# 0          No          No              No  monthly              Yes
# 1          No          No              No   yearly               No
# 2          No          No              No  monthly              Yes
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# ...

# %%
count(df['StreamingMovies'])
df['StreamingMovies'] = df['StreamingMovies'].replace('StreamingMovies','No')

# %%
count(df['PaperlessBilling'])
# Out:
# <function __main__.count(plot2)>

# %%
count(df['PaymentMethod'])
# Out:
# <function __main__.count(plot2)>

# %%
df['PaymentMethod'] = df['PaymentMethod'].replace('Bank tranfer (automatic)','Bank transfer')

# %%
df['PaymentMethod'] = df['PaymentMethod'].replace('Credit card (automatic)','Credit card')

# %%
df.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0            No             DSL             No  ...               No
# 1            No             DSL            Yes  ...              Yes
# 2            No             DSL            Yes  ...               No
# 3            No             DSL            Yes  ...              Yes
# 4            No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies Contract PaperlessBilling  \
# ...

# %%
count(df['Churn'])
# Out:
# <function __main__.count(plot2)>

# %%
def box(data):
    plt.figure(figsize=(10,5))
    sns.boxenplot(data)
    return box

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
df['TotalCharges'] = df['TotalCharges'].replace(' ', float('nan')).astype(float)

# %%
box(df['TotalCharges'])
# Out:
# <function __main__.box(data)>

# %%
box(df['MonthlyCharges'])
# Out:
# <function __main__.box(data)>

# %%
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df['TotalCharges'] = df['TotalCharges'].fillna(df['TotalCharges'].mean())

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df[df.MonthlyCharges>(df.MonthlyCharges.mean()+3*df.MonthlyCharges.std())]
# Out:
# Empty DataFrame
# Columns: [customerID, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162289    32.370865       64.761692   2283.300441
# std         0.368742    24.559231       30.090047   2265.000258
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    402.225000
# 50%         0.000000    29.000000       70.350000   1400.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for column in df.columns:
    if df[column].dtypes == 'object':
        df[column] = LabelEncoder().fit_transform(df[column])

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0        5375       0              0        1           0       1
# 1        3962       1              0        0           0      34
# 2        2564       1              0        0           0       2
# 3        5535       1              0        0           0      45
# 4        6511       0              0        0           0       2
#
#    PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0             0              0                0               0  ...
# 1             1              0                0               2  ...
# 2             1              0                0               2  ...
# 3             0              0                0               2  ...
# 4             1              0                1               0  ...
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
df= df.drop(['customerID'],axis=1)

# %%
cor = df.corr()

# %%
def hat(data1):
    plt.figure(figsize=(15,7))
    sns.heatmap(data1,annot=True,cmap="coolwarm")
    return hat

# %%
# hat(cor)

# %%
# hat(df.describe())

# %%
x = df.drop(['Churn'],axis=1)

# %%
len(df['Churn'])
# Out:
# 7043

# %%
y =df['Churn']

# %%
len(y)
# Out:
# 7043

# %%
 from sklearn.model_selection import train_test_split
 from sklearn.metrics import r2_score
 from sklearn.linear_model import LogisticRegression

# scores = []

# for i in range(1000):
#     xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.25, random_state=i)

#     # Make sure that x and y have the same number of samples
#     assert xtrain.shape[0] == ytrain.shape[0], f"Mismatch in number of samples for iteration {i}"

#     model = LogisticRegression()
#     model.fit(xtrain, ytrain)
#     y_pred = model.predict(xtest)
#     scores.append(r2_score(ytest, y_pred))

# %%
# np.argmax(scores)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.25, random_state=886)

# %%
model = LogisticRegression()
model.fit(xtrain,ytrain)
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(xtest,ytest)
# Out:
# 0.8222600795002839

# %%
# bagged_model  = BaggingClassifier(
#         base_estimator=LogisticRegression(),
#         n_estimators=100,
#         max_samples=.80,
#         random_state=886,
#         oob_score=True
# )
# from sklearn.model_selection import cross_val_score
# fs = cross_val_score(bagged_model,x,y,cv=5)
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...

# %%
fs.mean()
# Out:
# 0.8026429124459643

# %%
from sklearn.ensemble import RandomForestClassifier
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=7)
model3 = RandomForestClassifier()
model3.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model3.score(xtest,ytest)
# Out:
# 0.9505962521294719

# %%
scores1 = []
for i in range(20):
    xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.25, random_state=i)

    # Make sure that x and y have the same number of samples
    assert xtrain.shape[0] == ytrain.shape[0], f"Mismatch in number of samples for iteration {i}"

    model4 = RandomForestClassifier()
    model4.fit(xtrain, ytrain)
    y_pred1 = model4.predict(xtest)
    print(scores1.append(r2_score(ytest, y_pred1)))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
np.argmax(scores1)
# Out:
# 7

# %%
 from sklearn.tree import DecisionTreeClassifier

# %%
model4 = DecisionTreeClassifier()

# %%
model4.fit(xtrain,ytrain)
y2 =model4.predict(xtest)
r2_score(ytest,y2)
# Out:
# -0.4201612903225804

# %%
from sklearn.svm import SVC

# %%
# Out:
# SVC()

# %%
model5.score(xtest,ytest)
# Out:
# 0.7359454855195912

# %%
Xtrain,Xtest,Ytrain,Ytest = train_test_split(x,y,test_size=.25,random_state=7)

# %%
model5 = SVC()
model5.fit(Xtrain,Ytrain)
# Out:
# SVC()

# %%
y3 = model5.predict(Xtest)

# %%
r2_score(Ytest,y3)
# Out:
# -0.37363494539781605

# %%
model6 = RandomForestClassifier()
model6.fit(x_train,y_train)
y_pred = model6.predict(x_test)

# %%
model6.score(x_test,y_test)
# Out:
# 0.7995457126632595

# %%
r2_score(y_test,y_pred)
# Out:
# -0.0057679737504610085

# %%
pred = model.predict(xtest)
r2_score(ytest,pred)
# Out:
# 0.01816009557945053

# %%
model.score(xtest,ytest)
# Out:
# 0.8091993185689949
