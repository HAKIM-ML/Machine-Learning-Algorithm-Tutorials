# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('hiring.csv')

# %%
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df['experience'].fillna('eight', inplace=True)
label_mapping= {'five': 5, 'seven':7,'ten':10,'three':3,'two':2,'eleven':11}
df['new_exp'] = df['experience'].map(label_mapping)

# %%
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)  \
# 0      eight                    8.0                           9      50000
# 1      eight                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000
#
#    new_exp
# 0      NaN
# 1      NaN
# 2      5.0
# 3      2.0
# 4      7.0
# 5      3.0
# 6     10.0
# 7     11.0

# %%
median_test_score = df['test_score(out of 10)'].median()

# %%
median_test_score
# Out:
# 8.0

# %%
error = df['test_score(out of 10)'].fillna(median_test_score)

# %%
df = pd.concat([df, error], axis=1)

# %%
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)  \
# 0      eight                    8.0                           9      50000
# 1      eight                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000
#
#    new_exp  test_score(out of 10)
# 0      NaN                    8.0
# 1      NaN                    8.0
# 2      5.0                    6.0
# 3      2.0                   10.0
# 4      7.0                    9.0
# 5      3.0                    7.0
# 6     10.0                    8.0
# ...

# %%
import pandas as pd

# Assuming 'df' is your DataFrame and you want to rename 'old_column_name' to 'new_column_name'
df1 = df.rename(columns={'test_score(out of 10': 'new_column_name'})

# %%
df2 = df1.drop(['experience'],axis=1)

# %%
df2
# Out:
#    test_score(out of 10)  interview_score(out of 10)  salary($)  new_exp  \
# 0                    8.0                           9      50000      NaN
# 1                    8.0                           6      45000      NaN
# 2                    6.0                           7      60000      5.0
# 3                   10.0                          10      65000      2.0
# 4                    9.0                           6      70000      7.0
# 5                    7.0                          10      62000      3.0
# 6                    NaN                           7      72000     10.0
# 7                    7.0                           8      80000     11.0
#
#    test_score(out of 10)
# 0                    8.0
# 1                    8.0
# 2                    6.0
# 3                   10.0
# 4                    9.0
# 5                    7.0
# 6                    8.0
# 7                    7.0

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
df3 = df2.iloc[:, 1:]

# %%
df3
# Out:
#    interview_score(out of 10)  salary($)  new_exp  test_score(out of 10)
# 0                           9      50000      NaN                    8.0
# 1                           6      45000      NaN                    8.0
# 2                           7      60000      5.0                    6.0
# 3                          10      65000      2.0                   10.0
# 4                           6      70000      7.0                    9.0
# 5                          10      62000      3.0                    7.0
# 6                           7      72000     10.0                    8.0
# 7                           8      80000     11.0                    7.0

# %%
df4 = df3.fillna(6.333)

# %%
df4
# Out:
#    interview_score(out of 10)  salary($)  new_exp  test_score(out of 10)
# 0                           9      50000    6.333                    8.0
# 1                           6      45000    6.333                    8.0
# 2                           7      60000    5.000                    6.0
# 3                          10      65000    2.000                   10.0
# 4                           6      70000    7.000                    9.0
# 5                          10      62000    3.000                    7.0
# 6                           7      72000   10.000                    8.0
# 7                           8      80000   11.000                    7.0

# %%
x = df.drop(['salary($)'],axis=1)

# %%
y = df['salary($)']

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=.25,random_state=42)
